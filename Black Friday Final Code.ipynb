# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_csv("/Users/ishaankadle/Downloads/train.csv")
data_test=pd.read_csv("/Users/ishaankadle/Downloads/test.csv")

df=data.copy()
df_test=data_test.copy()

# %%
#Converting the Product ID into numbers that can be used.
df['Product_ID_usable']=df['Product_ID'].str.replace('P', '').astype(int)
df_test['Product_ID_usable']=df_test['Product_ID'].str.replace('P', '').astype(int)

# %%
pd.get_dummies(df.Gender,drop_first=True).astype(int)
pd.get_dummies(df_test.Gender,drop_first=True).astype(int)
df["Gender_Encoded"]=pd.get_dummies(df.Gender,drop_first=True).astype(int)
df_test["Gender_Encoded"]=pd.get_dummies(df_test.Gender,drop_first=True).astype(int)

# %%
city_encoded=pd.get_dummies(df['City_Category'], drop_first=True).astype(int)
city_encoded_test=pd.get_dummies(df_test['City_Category'], drop_first=True).astype(int)

df = pd.concat([df, city_encoded], axis=1)
df_test = pd.concat([df_test, city_encoded_test], axis=1)

# %%
df=df.drop(columns=['Gender','City_Category'])
df_test=df_test.drop(columns=['Gender','City_Category'])

# %%
age_encoder_1={
    '0-17': 8.5,
    '18-25': 21.5,
    '26-35': 30.5,
    '36-45': 40.5,
    '46-50': 48,
    '51-55': 53,
    '55+': 55
}

df['Age'] = df['Age'].map(age_encoder_1)
df_test['Age'] = df_test['Age'].map(age_encoder_1)

# %%
stay_encoder={
    '0': 0,
    '1': 1,
    '2': 2,
    '3': 3,
    '4+': 4
}
df['Stay'] = df['Stay_In_Current_City_Years'].map(stay_encoder)
df_test['Stay'] = df_test['Stay_In_Current_City_Years'].map(stay_encoder)

# %%
df=df.drop(columns=['Stay_In_Current_City_Years'])
df_test=df_test.drop(columns=['Stay_In_Current_City_Years'])

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Age', 'Occupation', 'Marital_Status',
#        'Product_Category_1', 'Product_Category_2', 'Product_Category_3',
#        'Purchase', 'Product_ID_usable', 'Gender_Encoded', 'B', 'C', 'Stay'],
#       dtype='object')

# %%
df.dtypes
# Out:
# User_ID                 int64
# Product_ID             object
# Age                   float64
# Occupation              int64
# Marital_Status          int64
# Product_Category_1      int64
# Product_Category_2    float64
# Product_Category_3    float64
# Purchase                int64
# Product_ID_usable       int64
# Gender_Encoded          int64
# B                       int64
# C                       int64
# Stay                    int64
# dtype: object

# %%
df['Product_Category_2'].fillna(df.Product_Category_2.mean(),inplace=True)
df_test['Product_Category_2'].fillna(df_test.Product_Category_2.mean(),inplace=True)

df['Product_Category_3'].fillna(0,inplace=True)
df_test['Product_Category_3'].fillna(0,inplace=True)
# Out:
# /var/folders/mm/0szfp9_x6bb9bgc1tpkndv340000gn/T/ipykernel_70001/3893328079.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Product_Category_2'].fillna(df.Product_Category_2.mean(),inplace=True)
# /var/folders/mm/0szfp9_x6bb9bgc1tpkndv340000gn/T/ipykernel_70001/3893328079.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test['Product_Category_2'].fillna(df_test.Product_Category_2.mean(),inplace=True)
# /var/folders/mm/0szfp9_x6bb9bgc1tpkndv340000gn/T/ipykernel_70001/3893328079.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Product_Category_3'].fillna(0,inplace=True)
# /var/folders/mm/0szfp9_x6bb9bgc1tpkndv340000gn/T/ipykernel_70001/3893328079.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test['Product_Category_3'].fillna(0,inplace=True)

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Age', 'Occupation', 'Marital_Status',
#        'Product_Category_1', 'Product_Category_2', 'Product_Category_3',
#        'Purchase', 'Product_ID_usable', 'Gender_Encoded', 'B', 'C', 'Stay'],
#       dtype='object')

# %%
X_train = df[['Product_ID_usable','User_ID','Age', 'Occupation', 'Marital_Status',
       'Gender_Encoded', 'B', 'C', 'Stay', 'Product_Category_1',
             'Product_Category_2','Product_Category_3']]

# %%
Y_train = df['Purchase']

# %%
X_test = df_test[['Product_ID_usable','User_ID','Age', 'Occupation', 'Marital_Status',
       'Gender_Encoded', 'B', 'C', 'Stay', 'Product_Category_1',
             'Product_Category_2','Product_Category_3',]]

# %%
import numpy as np
from sklearn.ensemble import (
    HistGradientBoostingRegressor,
    StackingRegressor,
    RandomForestRegressor
)
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV

# %%
rf_model = RandomForestRegressor() 
hgb_model = HistGradientBoostingRegressor(learning_rate= 0.1,max_depth=10, max_iter= 1000, min_samples_leaf= 5) 
lgbm_model = LGBMRegressor(learning_rate= 0.1, max_depth= 20, n_estimators= 500, num_leaves= 100)
xgb_model = XGBRegressor(colsample_bytree= 0.6, gamma= 0, learning_rate= 0.1, max_depth= 10, min_child_weight= 7, n_estimators= 400, subsample= 1.0) 
catboost_model = CatBoostRegressor()

# %%
param_grid_xgb ={
    'max_depth': [3,5,10],
    'learning_rate': [0.01, 0.1],
    'n_estimators': [100, 400],
    'min_child_weight': [3, 7],
    'gamma': [0, 0.3],
    'subsample': [0.6, 1.0],
    'colsample_bytree': [0.6, 1.0]
}

grid_search_xgb = GridSearchCV(estimator=xgb_model, param_grid=param_grid_xgb, 
                               cv=5, scoring='neg_mean_squared_error', 
                               verbose=2, n_jobs=-1)

grid_search_xgb.fit(X_train, Y_train)

print("Best parameters for XGBRegressor: ", grid_search_xgb.best_params_)
# Out:
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# Best parameters for XGBRegressor:  {'colsample_bytree': 0.6, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 7, 'n_estimators': 400, 'subsample': 1.0}

# %%
stacking_model = StackingRegressor(
    estimators=[
        ('rf', rf_model),  
        ('hgb', hgb_model),
        ('lgbm', lgbm_model),
        ('xgb', xgb_model),
        ('catboost', catboost_model)
    ],
    final_estimator=LinearRegression()
)

stacking_model.fit(X_train, Y_train)
df_test['Purchase'] = stacking_model.predict(X_test)  

df_test['Purchase'] = np.round(df_test['Purchase'])
#As purchase cant be negative
df_test["Purchase"] = np.where(df_test["Purchase"] < 0, 0, df_test["Purchase"])
# Out:
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.6; total time=   3.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=400, subsample=0.6; total time=   9.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=100, subsample=0.6; total time=   3.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=100, subsample=1.0; total time=   2.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=400, subsample=0.6; total time=   9.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.6; total time=   4.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=400, subsample=0.6; total time=  15.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=400, subsample=1.0; total time=  13.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=7, n_estimators=400, subsample=1.0; total time=  13.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=100, subsample=1.0; total time=   8.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=400, subsample=0.6; total time=  37.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=100, subsample=0.6; total time=   8.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=100, subsample=1.0; total time=   9.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=400, subsample=0.6; total time=  38.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.6; total time=   3.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.6; total time=   3.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=400, subsample=0.6; total time=  11.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=400, subsample=1.0; total time=   9.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=7, n_estimators=400, subsample=0.6; total time=  11.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=7, n_estimators=400, subsample=1.0; total time=   9.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=400, subsample=1.0; total time=  12.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=7, n_estimators=100, subsample=0.6; total time=   4.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=7, n_estimators=100, subsample=1.0; total time=   3.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=7, n_estimators=400, subsample=0.6; total time=  15.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=100, subsample=0.6; total time=   8.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=100, subsample=1.0; total time=   8.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=400, subsample=1.0; total time=  28.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=7, n_estimators=100, subsample=0.6; total time=   8.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=7, n_estimators=400, subsample=0.6; total time=  33.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=7, n_estimators=400, subsample=1.0; total time=  25.2s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=100, subsample=0.6; total time=   3.5s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=100, subsample=1.0; total time=   3.1s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=100, subsample=1.0; total time=   3.1s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=400, subsample=1.0; total time=   9.5s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.6; total time=   4.8s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=100, subsample=1.0; total time=   4.2s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=400, subsample=0.6; total time=  17.5s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.01, max_depth=5, min_child_weight=7, n_estimators=100, subsample=0.6; total time=   4.6s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.01, max_depth=5, min_child_weight=7, n_estimators=400, subsample=0.6; total time=  16.8s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.01, max_depth=5, min_child_weight=7, n_estimators=400, subsample=1.0; total time=  14.0s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=400, subsample=0.6; total time=  38.4s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=100, subsample=0.6; total time=   9.0s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=100, subsample=1.0; total time=   8.8s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=400, subsample=0.6; total time=  36.1s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.6; total time=   3.2s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, subsample=1.0; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=400, subsample=0.6; total time=  10.7s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=400, subsample=1.0; total time=   8.3s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=3, min_child_weight=7, n_estimators=400, subsample=0.6; total time=  10.7s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=3, min_child_weight=7, n_estimators=400, subsample=1.0; total time=   8.7s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=400, subsample=0.6; total time=  14.3s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=5, min_child_weight=7, n_estimators=100, subsample=1.0; total time=   3.7s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=5, min_child_weight=7, n_estimators=100, subsample=1.0; total time=   3.7s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=5, min_child_weight=7, n_estimators=400, subsample=1.0; total time=  12.2s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=100, subsample=0.6; total time=   8.7s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=100, subsample=1.0; total time=   8.2s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=400, subsample=0.6; total time=  31.0s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=10, min_child_weight=7, n_estimators=100, subsample=1.0; total time=   8.0s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=10, min_child_weight=7, n_estimators=400, subsample=0.6; total time=  30.5s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=10, min_child_weight=7, n_estimators=400, subsample=1.0; total time=  24.8s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=100, subsample=0.6; total time=   3.5s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=100, subsample=1.0; total time=   2.8s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=400, subsample=0.6; total time=  11.7s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=100, subsample=1.0; total time=   4.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=400, subsample=0.6; total time=  17.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=400, subsample=1.0; total time=  14.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=7, n_estimators=400, subsample=1.0; total time=  14.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=100, subsample=1.0; total time=   9.5s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=400, subsample=0.6; total time=  39.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=100, subsample=0.6; total time=   9.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=100, subsample=1.0; total time=  10.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=400, subsample=0.6; total time=  38.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.6; total time=   3.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, subsample=1.0; total time=   2.4s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=400, subsample=0.6; total time=  10.8s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=400, subsample=1.0; total time=
# 824:	learn: 2654.8593820	total: 13.8s	remaining: 2.93s
# 825:	learn: 2654.7515829	total: 13.8s	remaining: 2.91s
# 826:	learn: 2654.6604957	total: 13.8s	remaining: 2.89s
# 827:	learn: 2654.5045263	total: 13.8s	remaining: 2.88s
# 828:	learn: 2654.4059884	total: 13.9s	remaining: 2.86s
# 829:	learn: 2654.2901173	total: 13.9s	remaining: 2.84s
# 830:	learn: 2654.1940525	total: 13.9s	remaining: 2.83s
# 831:	learn: 2654.0281183	total: 13.9s	remaining: 2.81s
# 832:	learn: 2653.9036043	total: 13.9s	remaining: 2.79s
# 833:	learn: 2653.7413214	total: 13.9s	remaining: 2.77s
# 834:	learn: 2653.6199039	total: 13.9s	remaining: 2.76s
# 835:	learn: 2653.5365191	total: 14s	remaining: 2.74s
# 836:	learn: 2653.3316946	total: 14s	remaining: 2.72s
# 837:	learn: 2653.2449439	total: 14s	remaining: 2.71s
# 838:	learn: 2653.0365749	total: 14s	remaining: 2.69s
# 839:	learn: 2652.9273971	total: 14s	remaining: 2.67s
# 840:	learn: 2652.8241593	total: 14.1s	remaining: 2.67s
# 841:	learn: 2652.6943961	total: 14.1s	remaining: 2.65s
# 842:	learn: 2652.5619419	total: 14.2s	remaining: 2.64s
# 843:	learn: 2652.4783089	total: 14.2s	remaining: 2.62s
# 844:	learn: 2652.3447998	total: 14.2s	remaining: 2.6s
# 845:	learn: 2652.2325607	total: 14.2s	remaining: 2.59s
# 846:	learn: 2652.0973578	total: 14.2s	remaining: 2.57s
# 847:	learn: 2652.0270763	total: 14.3s	remaining: 2.55s
# 848:	learn: 2651.9164154	total: 14.3s	remaining: 2.54s
# 849:	learn: 2651.8137483	total: 14.3s	remaining: 2.52s
# 850:	learn: 2651.7355925	total: 14.3s	remaining: 2.5s
# 851:	learn: 2651.6334913	total: 14.3s	remaining: 2.49s
# 852:	learn: 2651.5116080	total: 14.3s	remaining: 2.47s
# 853:	learn: 2651.3636356	total: 14.3s	remaining: 2.45s
# 854:	learn: 2651.0888467	total: 14.4s	remaining: 2.44s
# 855:	learn: 2650.9812611	total: 14.4s	remaining: 2.42s
# 856:	learn: 2650.8295834	total: 14.4s	remaining: 2.4s
# 857:	learn: 2650.7236037	total: 14.4s	remaining: 2.38s
# 858:	learn: 2650.6142469	total: 14.4s	remaining: 2.37s
# 859:	learn: 2650.3998886	total: 14.4s	remaining: 2.35s
# 860:	learn: 2650.3392287	total: 14.5s	remaining: 2.33s
# 861:	learn: 2650.1811740	total: 14.5s	remaining: 2.32s
# 862:	learn: 2650.0397952	total: 14.5s	remaining: 2.3s
# 863:	learn: 2649.9554436	total: 14.5s	remaining: 2.28s
# 864:	learn: 2649.8842826	total: 14.5s	remaining: 2.27s
# 865:	learn: 2649.7178759	total: 14.5s	remaining: 2.25s
# 866:	learn: 2649.4470772	total: 14.6s	remaining: 2.23s
# 867:	learn: 2649.3148108	total: 14.6s	remaining: 2.22s
# 868:	learn: 2649.1820971	total: 14.6s	remaining: 2.2s
# 869:	learn: 2649.0893120	total: 14.6s	remaining: 2.18s
# 870:	learn: 2648.9406827	total: 14.6s	remaining: 2.17s
# 871:	learn: 2648.8323310	total: 14.6s	remaining: 2.15s
# 872:	learn: 2648.7469638	total: 14.7s	remaining: 2.13s
# 873:	learn: 2648.6640322	total: 14.7s	remaining: 2.12s
# 874:	learn: 2648.5959933	total: 14.7s	remaining: 2.1s
# 875:	learn: 2648.4199446	total: 14.7s	remaining: 2.08s
# 876:	learn: 2648.3113043	total: 14.7s	remaining: 2.06s
# 877:	learn: 2648.1502137	total: 14.7s	remaining: 2.05s
# 878:	learn: 2647.9819599	total: 14.8s	remaining: 2.03s
# 879:	learn: 2647.7931704	total: 14.8s	remaining: 2.01s
# 880:	learn: 2647.7228188	total: 14.8s	remaining: 2s
# 881:	learn: 2647.5880489	total: 14.8s	remaining: 1.98s
# 882:	learn: 2647.4939316	total: 14.8s	remaining: 1.96s
# 883:	learn: 2647.3975250	total: 14.8s	remaining: 1.95s
# 884:	learn: 2647.2553324	total: 14.8s	remaining: 1.93s
# 885:	learn: 2647.1014958	total: 14.9s	remaining: 1.91s
# 886:	learn: 2646.8504860	total: 15s	remaining: 1.9s
# 887:	learn: 2646.7780830	total: 15s	remaining: 1.89s
# 888:	learn: 2646.6759066	total: 15s	remaining: 1.87s
# 889:	learn: 2646.5702916	total: 15s	remaining: 1.85s
# 890:	learn: 2646.4389005	total: 15s	remaining: 1.84s
# 891:	learn: 2646.2167942	total: 15s	remaining: 1.82s
# 892:	learn: 2646.1252616	total: 15.1s	remaining: 1.8s
# 893:	learn: 2645.9682689	total: 15.1s	remaining: 1.79s
# 894:	learn: 2645.8779237	total: 15.1s	remaining: 1.77s
# 895:	learn: 2645.7470696	total: 15.1s	remaining: 1.75s
# 896:	learn: 2645.6430310	total: 15.1s	remaining: 1.74s
# 897:	learn: 2645.4903588	total: 15.1s	remaining: 1.72s
# 898:	learn: 2645.3883138	total: 15.2s	remaining: 1.7s
# 899:	learn: 2645.2246296	total: 15.2s	remaining: 1.69s
# 900:	learn: 2645.0580584	total: 15.2s	remaining: 1.67s
# 901:	learn: 2644.8683047	total: 15.2s	remaining: 1.65s
# 902:	learn: 2644.7127018	total: 15.2s	remaining: 1.63s
# 903:	learn: 2644.6302464	total: 15.2s	remaining: 1.62s
# 904:	learn: 2644.4809267	total: 15.2s	remaining: 1.6s
# 905:	learn: 2644.3623962	total: 15.3s	remaining: 1.58s
# 906:	learn: 2644.2769469	total: 15.3s	remaining: 1.57s
# 907:	learn: 2644.1920660	total: 15.3s	remaining: 1.55s
# 908:	learn: 2644.0756550	total: 15.3s	remaining: 1.53s
# 909:	learn: 2643.9432593	total: 15.3s	remaining: 1.51s
# 910:	learn: 2643.9011252	total: 15.3s	remaining: 1.5s
# 911:	learn: 2643.7212901	total: 15.4s	remaining: 1.48s
# 912:	learn: 2643.6239867	total: 15.4s	remaining: 1.46s
# 913:	learn: 2643.5065485	total: 15.4s	remaining: 1.45s
# 914:	learn: 2643.2512356	total: 15.4s	remaining: 1.43s
# 915:	learn: 2643.1765356	total: 15.4s	remaining: 1.41s
# 916:	learn: 2643.1056496	total: 15.4s	remaining: 1.4s
# 917:	learn: 2642.9908615	total: 15.4s	remaining: 1.38s
# 918:	learn: 2642.9346452	total: 15.5s	remaining: 1.36s
# 919:	learn: 2642.8438302	total: 15.5s	remaining: 1.34s
# 920:	learn: 2642.7892723	total: 15.5s	remaining: 1.33s
# 921:	learn: 2642.7159738	total: 15.5s	remaining: 1.31s
# 922:	learn: 2642.6205239	total: 15.5s	remaining: 1.29s
# 923:	learn: 2642.4678868	total: 15.5s	remaining: 1.28s
# 924:	learn: 2642.3553270	total: 15.5s	remaining: 1.26s
# 925:	learn: 2642.2850602	total: 15.6s	remaining: 1.24s
# 926:	learn: 2642.2474161	total: 15.6s	remaining: 1.23s
# 927:	learn: 2642.1346763	total: 15.6s	remaining: 1.21s
# 928:	learn: 2642.0307065	total: 15.6s	remaining: 1.19s
# 929:	learn: 2641.9104654	total: 15.6s	remaining: 1.18s
# 930:	learn: 2641.7831675	total: 15.6s	remaining: 1.16s
# 931:	learn: 2641.6770483	total: 15.6s	remaining: 1.14s
# 932:	learn: 2641.6102342	total: 15.7s	remaining: 1.12s
# 933:	learn: 2641.4836412	total: 15.7s	remaining: 1.11s
# 934:	learn: 2641.3665578	total: 15.7s	remaining: 1.09s
# 935:	learn: 2641.3067762	total: 15.8s	remaining: 1.08s
# 936:	learn: 2641.1999422	total: 15.8s	remaining: 1.06s
# 937:	learn: 2641.1398452	total: 15.8s	remaining: 1.05s
# 938:	learn: 2641.0798604	total: 15.8s	remaining: 1.03s
# 939:	learn: 2640.9959379	total: 15.9s	remaining: 1.01s
# 940:	learn: 2640.9327185	total: 15.9s	remaining: 996ms
# 941:	learn: 2640.7959892	total: 15.9s	remaining: 979ms
# 942:	learn: 2640.7412157	total: 15.9s	remaining: 962ms
# 943:	learn: 2640.4862654	total: 15.9s	remaining: 945ms
# 944:	learn: 2640.3448516	total: 15.9s	remaining: 928ms
# 945:	learn: 2640.2764499	total: 16s	remaining: 911ms
# 946:	learn: 2640.1948668	total: 16s	remaining: 894ms
# 947:	learn: 2640.1134471	total: 16s	remaining: 877ms
# 948:	learn: 2639.9600207	total: 16s	remaining: 860ms
# 949:	learn: 2639.8339168	total: 16s	remaining: 843ms
# 950:	learn: 2639.7694413	total: 16s	remaining: 826ms
# 951:	learn: 2639.6499297	total: 16.1s	remaining: 809ms
# 952:	learn: 2639.5705382	total: 16.1s	remaining: 792ms
# 953:	learn: 2639.4431363	total: 16.1s	remaining: 776ms
# 954:	learn: 2639.3825166	total: 16.1s	remaining: 759ms
# 955:	learn: 2639.2591803	total: 16.1s	remaining: 742ms
# 956:	learn: 2639.1448874	total: 16.1s	remaining: 725ms
# 957:	learn: 2639.0492678	total: 16.1s	remaining: 708ms
# 958:	learn: 2638.9534694	total: 16.2s	remaining: 691ms
# 959:	learn: 2638.8733018	total: 16.2s	remaining: 674ms
# 960:	learn: 2638.6806245	total: 16.2s	remaining: 657ms
# 961:	learn: 2638.6291502	total: 16.2s	remaining: 640ms
# 962:	learn: 2638.5347190	total: 16.2s	remaining: 623ms
# 963:	learn: 2638.4185160	total: 16.2s	remaining: 606ms
# 964:	learn: 2638.3111675	total: 16.2s	remaining: 589ms
# 965:	learn: 2638.2479339	total: 16.3s	remaining: 572ms
# 966:	learn: 2638.1346639	total: 16.3s	remaining: 556ms
# 967:	learn: 2638.0123348	total: 16.3s	remaining: 539ms
# 968:	learn: 2637.8924235	total: 16.3s	remaining: 522ms
# 969:	learn: 2637.7386933	total: 16.3s	remaining: 505ms
# 970:	learn: 2637.6257478	total: 16.3s	remaining: 488ms
# 971:	learn: 2637.5528802	total: 16.4s	remaining: 471ms
# 972:	learn: 2637.4659138	total: 16.4s	remaining: 454ms
# 973:	learn: 2637.3213430	total: 16.4s	remaining: 437ms
# 974:	learn: 2637.2178908	total: 16.4s	remaining: 421ms
# 975:	learn: 2637.1133746	total: 16.4s	remaining: 404ms
# 976:	learn: 2636.9174991	total: 16.4s	remaining: 387ms
# 977:	learn: 2636.8364905	total: 16.4s	remaining: 370ms
# 978:	learn: 2636.6384043	total: 16.5s	remaining: 353ms
# 979:	learn: 2636.5263452	total: 16.5s	remaining: 336ms
# 980:	learn: 2636.4148177	total: 16.5s	remaining: 319ms
# 981:	learn: 2636.2996868	total: 16.5s	remaining: 303ms
# 982:	learn: 2636.2054300	total: 16.5s	remaining: 286ms
# 983:	learn: 2636.0647976	total: 16.6s	remaining: 270ms
# 984:	learn: 2635.9501869	total: 16.6s	remaining: 253ms
# 985:	learn: 2635.8445365	total: 16.7s	remaining: 237ms
# 986:	learn: 2635.7433942	total: 16.7s	remaining: 220ms
# 987:	learn: 2635.6930452	total: 16.7s	remaining: 203ms
# 988:	learn: 2635.5841968	total: 16.7s	remaining: 186ms
# 989:	learn: 2635.5220148	total: 16.7s	remaining: 169ms
# 990:	learn: 2635.3921739	total: 16.7s	remaining: 152ms
# 991:	learn: 2635.2782531	total: 16.8s	remaining: 135ms
# 992:	learn: 2635.1311397	total: 16.8s	remaining: 118ms
# 993:	learn: 2635.0194514	total: 16.8s	remaining: 101ms
# 994:	learn: 2634.9278694	total: 16.8s	remaining: 84.5ms
# 995:	learn: 2634.8134532	total: 16.8s	remaining: 67.6ms
# 996:	learn: 2634.6827966	total: 16.8s	remaining: 50.7ms
# 997:	learn: 2634.5562240	total: 16.9s	remaining: 33.8ms
# 998:	learn: 2634.4635641	total: 16.9s	remaining: 16.9ms
# 999:	learn: 2634.3954405	total: 16.9s	remaining: 0us

# %%
df_test[['User_ID', 'Product_ID', 'Purchase']].to_csv('/Users/ishaankadle/Downloads/solutionabk.csv', index=False)
